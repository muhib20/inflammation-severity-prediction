# %%
#Random Forest REGRESSION (Severity 0–5)
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# %%
rf_reg = RandomForestRegressor(
    n_estimators=300,
    random_state=42
)

# %%
rf_pipe = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("model", rf_reg)
])

# %%
gkf = GroupKFold(n_splits=5)

mae_scores = []

# %%
for train_idx, test_idx in gkf.split(X, y, groups=pat_id):
    X_tr, X_te = X.iloc[train_idx], X.iloc[test_idx]
    y_tr, y_te = y.iloc[train_idx], y.iloc[test_idx]

    rf_pipe.fit(X_tr, y_tr)        # TRAIN
    preds = rf_pipe.predict(X_te) # PREDICT severity (0–5)

# %%
    mae = mean_absolute_error(y_te, preds)
    mae_scores.append(mae)

# %%
print("Random Forest REGRESSION (Severity 0–5) with GroupKFold")
print(f"MAE: {np.mean(mae_scores):.3f} ± {np.std(mae_scores):.3f}")
# Out:
# Random Forest REGRESSION (Severity 0–5) with GroupKFold
# MAE: 0.609 ± 0.000
